# %%
import numpy as np
import statistics as stat

# %%
population=np.random.randint(0,100,50)
population
# Out:
# array([78,  9, 75, 74, 96, 36, 28, 16, 20, 71, 68, 97, 58, 39, 73, 84, 14,
#        73, 15, 84, 62, 66, 52, 83, 49, 66, 20, 84, 96, 81,  0, 83, 32, 88,
#        38, 69, 54, 41, 99, 45, 18, 26, 58,  0, 42, 94, 11, 67, 28, 34])

# %%
np.mean(population)
# Out:
# 53.88

# %%
np.median(population)
# Out:
# 58.0

# %%
stat.mode(population)
# Out:
# 84

# %%
sample=np.random.choice(population,20)

# %%
np.mean(sample)
# Out:
# 67.15

# %%
np.median(sample)
# Out:
# 71.5

# %%
stat.mode(sample)
# Out:
# 78

# %%
sample2=np.random.choice(population,5)

# %%
np.mean(sample2)
# Out:
# 59.8

# %%
sample3=np.random.choice(population,5)

# %%
np.mean(sample3)
# Out:
# 57.6

# %%
sample4=np.random.choice(population,5)

# %%
np.mean(sample4)
# Out:
# 36.2

# %%
print(sample)
print(20*"=")
print(sample2)
print(20*"=")
print(sample3)
print(20*"=")
print(sample4)
print(20*"=")
# Out:
# [66 78 83 28 75 36 38 74 69 42 88 54 97 83 99 96 58 69 32 78]
# ...
# [ 0 58 83 74 84]
# ...
# [88 96  9 26 69]
# ...
# [32  9 62 78  0]
# ...

# %%
all_sample=[sample,sample2,sample3,sample4]
mean_all=[]
for sample in all_sample:
    mean_all.extend(sample)
np.mean(mean_all)
# Out:
# 60.31428571428572

# %%
clt=np.random.choice(population,35)

# %%
import matplotlib.pyplot as plt
plt.plot(clt)

# %%
import seaborn as sns
sns.distplot(clt)
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# <h1>Central limit theorem</h1>

# %%
population=np.random.binomial(10,0.5,10000)

# %%
sns.distplot(population)
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
len(population)
# Out:
# 10000

# %%
size=int(len(population)*0.3)

# %%
sample_mean=[]
for i in range(1,31):
    sample=np.random.choice(population,size=size)
    sample_mean.append(np.mean(sample))

# %%
sns.distplot(sample_mean)
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sample_mean=[]
for i in range(1,3001):
    sample=np.random.choice(population,size=size)
    sample_mean.append(np.mean(sample))

# %%
sns.distplot(sample_mean)
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import scipy.stats as stats

# %%
stats.norm.ppf(q=0.95)
# Out:
# 1.6448536269514722

# %%
stats.norm.ppf(q=0.975)
# Out:
# 1.959963984540054

# %%
z_score=stats.norm.ppf(q=0.999) #z score

# %% [markdown]
# <h1>ppf func is for pdf and there is pmf</h1>
# <p>point est is mean of sample data</p>

# %%
t_score=stats.t.ppf(q=0.975,df=25)
print(t_score)
# Out:
# 2.059538552753294

# %%
margin_of_error=z_score*(np.std(mean_all)/np.sqrt(20))

# %%
np.mean(mean_all)-margin_of_error
# Out:
# 40.54109579046973

# %%
np.mean(mean_all)+margin_of_error
# Out:
# 80.0874756381017

# %% [markdown]
# <h1>Z test</h1>

# %%
from numpy.random import randn
population=randn(100)

# %%
sns.distplot(population)
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
print(np.mean(population))
# Out:
# 0.17519772754368076

# %%
null_mean=0.17519772754368076

# %%
print(np.std(population))
# Out:
# 1.0290142267952067

# %%
# confidence_intervel=95%(0.95)
alpha=0.05

# %%
p>0.05(alpha) accept null hypothysis
p<0.05(alpha) reject

# %%
from statsmodels.stats.weightstats import ztest

# %%
z_scoree,p_value=ztest(population,value=null_mean,alternative='larger')

# %%
if p_value>alpha:
    print("accept null hypothesis")
else:
    print("reject")
# Out:
# accept null hypothesis

# %%
p_value
# Out:
# 0.5
