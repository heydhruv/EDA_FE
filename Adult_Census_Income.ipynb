# %%
# from scipy.io import arff
# import pandas as pd

# phishing=arff.loadarff(r"C:\Users\Dhruv\Downloads\Training Dataset.arff")
# df = pd.DataFrame(phishing[0])
# df.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
income=pd.read_csv(r"C:\Users\Dhruv\Downloads\adult.csv")
income.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
# col=['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','salary']

# %%
income.columns=col
income.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  salary
# 0             0             0              13   United-States   <=50K
# ...

# %%
income.info()

# %%
# income.describe()

# %%
income.drop(['fnlwgt','capital_gain','capital_loss'],axis=1,inplace=True)

# %%
col=['age','workclass','education','education_num','marital_status','occupation','relationship','race','sex','hours_per_week','native_country','salary']

# %%
income.columns=col
income.head()
# Out:
#    age          workclass   education  education_num       marital_status  \
# 0   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 1   38            Private     HS-grad              9             Divorced
# 2   53            Private        11th              7   Married-civ-spouse
# 3   28            Private   Bachelors             13   Married-civ-spouse
# 4   37            Private     Masters             14   Married-civ-spouse
#
#            occupation    relationship    race      sex  hours_per_week  \
# 0     Exec-managerial         Husband   White     Male              13
# 1   Handlers-cleaners   Not-in-family   White     Male              40
# 2   Handlers-cleaners         Husband   Black     Male              40
# 3      Prof-specialty            Wife   Black   Female              40
# 4     Exec-managerial            Wife   White   Female              40
#
#    native_country  salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# ...

# %%
income.describe(include='all')

# %%
# cleaning the object type values of having leading or trailing spaces
# for i in income.columns:
#     if income[i].dtype()=='object':
#         income[i]=income[i].str.strip()

# %%
income['age'].isnull().sum()
# Out:
# 0

# %%
income['workclass'].isnull().sum()
# Out:
# 0

# %%
income['education'].isnull().sum()
# Out:
# 0

# %%
income['education_num'].isnull().sum()
# Out:
# 0

# %%
income['marital_status'].isnull().sum()
# Out:
# 0

# %%
income['occupation'].isnull().sum()
# Out:
# 0

# %%
income['relationship'].isnull().sum()
# Out:
# 0

# %%
income['race'].isnull().sum()
# Out:
# 0

# %%
income['sex'].isnull().sum()
# Out:
# 0

# %%
income['hours_per_week'].isnull().sum()
# Out:
# 0

# %%
income['native_country'].isnull().sum()
# Out:
# 0

# %%
income['salary'].isnull().sum()
# Out:
# 0

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'education', 'education_num', 'marital_status',
#        'occupation', 'relationship', 'race', 'sex', 'hours_per_week',
#        'native_country', 'salary'],
#       dtype='object')

# %%
income.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# hours_per_week    0
# native_country    0
# salary            0
# dtype: int64

# %%
income.shape
# Out:
# (32560, 12)

# %%
income_copy=income
income_copy.head()
# Out:
#    age          workclass   education  education_num       marital_status  \
# 0   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 1   38            Private     HS-grad              9             Divorced
# 2   53            Private        11th              7   Married-civ-spouse
# 3   28            Private   Bachelors             13   Married-civ-spouse
# 4   37            Private     Masters             14   Married-civ-spouse
#
#            occupation    relationship    race      sex  hours_per_week  \
# 0     Exec-managerial         Husband   White     Male              13
# 1   Handlers-cleaners   Not-in-family   White     Male              40
# 2   Handlers-cleaners         Husband   Black     Male              40
# 3      Prof-specialty            Wife   Black   Female              40
# 4     Exec-managerial            Wife   White   Female              40
#
#    native_country  salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# ...

# %%
income_copy=income_copy.replace('?',np.nan)

# %%
income_copy['native_country'] = income_copy['native_country'].replace(' ?' , np.nan )
income_copy['age'] = income_copy['age'].replace(' ?' , np.nan )
income_copy['workclass'] = income_copy['workclass'].replace(' ?' , np.nan )
income_copy['education'] = income_copy['education'].replace(' ?' , np.nan )
income_copy['education_num'] = income_copy['education_num'].replace(' ?' , np.nan )
income_copy['marital_status'] = income_copy['marital_status'].replace(' ?' , np.nan )
income_copy['occupation'] = income_copy['occupation'].replace(' ?' , np.nan )
income_copy['relationship'] = income_copy['relationship'].replace(' ?' , np.nan )
income_copy['race'] = income_copy['race'].replace(' ?' , np.nan )
income_copy['sex'] = income_copy['sex'].replace(' ?' , np.nan )
income_copy['hours_per_week'] = income_copy['hours_per_week'].replace(' ?' , np.nan )
income_copy['salary'] = income_copy['salary'].replace(' ?' , np.nan )

# %%
income_copy.isna().sum()
# Out:
# age                  0
# workclass         1836
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# hours_per_week       0
# native_country     583
# salary               0
# dtype: int64

# %% [markdown]
# <h1>replaced null values with mode values</h1>

# %%
income_copy['workclass']=income_copy['workclass'].fillna(income_copy['workclass'].mode()[0])
income_copy['occupation']=income_copy['occupation'].fillna(income_copy['occupation'].mode()[0])
income_copy['native_country']=income_copy['native_country'].fillna(income_copy['native_country'].mode()[0])

# %%
income_copy.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# hours_per_week    0
# native_country    0
# salary            0
# dtype: int64

# %%
income_copy['salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %% [markdown]
# <h1>replaced salary <=50K with 0 and >50K with 1 </h1>

# %%
income_copy['salary'] = income_copy['salary'].replace(' <=50K' , 0 )
income_copy['salary'] = income_copy['salary'].replace(' >50K' , 1 )

# %%
income_copy
# Out:
#        age          workclass    education  education_num  \
# 0       50   Self-emp-not-inc    Bachelors             13
# 1       38            Private      HS-grad              9
# 2       53            Private         11th              7
# 3       28            Private    Bachelors             13
# 4       37            Private      Masters             14
# ...    ...                ...          ...            ...
# 32555   27            Private   Assoc-acdm             12
# 32556   40            Private      HS-grad              9
# 32557   58            Private      HS-grad              9
# 32558   22            Private      HS-grad              9
# 32559   52       Self-emp-inc      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
income_copy[income_copy.duplicated()]
# Out:
#        age workclass      education  education_num       marital_status  \
# 351     33   Private      Bachelors             13   Married-civ-spouse
# 390     27   Private      Bachelors             13        Never-married
# 525     42   Private      Bachelors             13   Married-civ-spouse
# 562     24   Private        HS-grad              9        Never-married
# 569     24   Private        HS-grad              9        Never-married
# ...    ...       ...            ...            ...                  ...
# 32502   47   Private        HS-grad              9   Married-civ-spouse
# 32511   20   Private        HS-grad              9        Never-married
# 32526   22   Private   Some-college             10        Never-married
# 32556   40   Private        HS-grad              9   Married-civ-spouse
# 32558   22   Private        HS-grad              9        Never-married
#
#                occupation    relationship    race      sex  hours_per_week  \
# ...

# %%
income_copy = income_copy.drop_duplicates(keep= 'first')
income_copy.shape
# Out:
# (28164, 12)

# %%
plt.figure(figsize=(8, 8))
plt.suptitle('bivariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
sns.barplot(data=income_copy,x='sex',y='salary')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='salary'>

# %%
sns.kdeplot(income_copy['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(income_copy['hours_per_week'])
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Density'>

# %%
sns.scatterplot(income_copy.index,income_copy['education'])
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='education'>

# %%
sns.countplot(x=income_copy["sex"])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(20, 15))
plt.suptitle('test', fontsize=10, fontweight='bold', alpha=0.8, y=1.)

sns.countplot(x=income_copy["marital_status"])
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='count'>

# %%
plt.figure(figsize=(20, 15))
plt.suptitle('test', fontsize=10, fontweight='bold', alpha=0.8, y=1.)

sns.barplot(x=income_copy['education'],y=income_copy['education_num'])
# Out:
# <AxesSubplot:xlabel='education', ylabel='education_num'>

# %%
numeric_cols=['age','education_num','hours_per_week']
categorical_cols=['workclass','education','marital_status','occupation','relationship','race','sex','native_country','salary']

# %%
plt.figure(figsize=(20, 15))
plt.suptitle('test', fontsize=10, fontweight='bold', alpha=0.8, y=1.)

sns.barplot(x=income_copy['salary'],y=income_copy['hours_per_week'])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='hours_per_week'>

# %%
plt.figure(figsize=(20, 15))
plt.suptitle('test', fontsize=10, fontweight='bold', alpha=0.8, y=1.)

sns.barplot(x=income_copy['workclass'],y=income_copy['hours_per_week'])
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='hours_per_week'>

# %%
plt.figure(figsize=(20, 15))
plt.suptitle('test', fontsize=10, fontweight='bold', alpha=0.8, y=1.)

sns.barplot(x=income_copy['marital_status'],y=income_copy['age'])
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='age'>

# %%
income_copy["occupation"].value_counts().plot.pie(y=income_copy["occupation"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='occupation'>

# %%
income_copy["workclass"].value_counts().plot.pie(y=income_copy["workclass"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='workclass'>

# %%
income_copy["race"].value_counts().plot.pie(y=income_copy["race"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='race'>

# %%
# Out:
# <AxesSubplot:ylabel='native_country'>

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_cols)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=income_co[numeric_cols[i]],shade=True, color='r')
    plt.xlabel(numeric_cols[i])
    plt.tight_layout()
